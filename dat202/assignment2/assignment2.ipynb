# %%
import pandas as pd

# %%
from sqlalchemy import create_engine, text
# engine = create_engine('postgresql://username:password@localhost:5432/dbname')
engine = create_engine('postgresql:///cbowers')
connection = engine.connect()

# %%
sql = text("""
select
    c.client_id,
    c.name,
    s.companyname,
    count(1)
from
    sales s,
    clients c
where
    s.companyname = c.name
group by
    c.client_id , c.name, s.companyname
order by
    count(1) desc;
""")
result = connection.execute(sql)
df_report = pd.DataFrame(result.fetchall(), columns=result.keys())
connection.close 

df_report
# Out:
#     client_id                                 name  \
# 0         602                  Comcast Corporation
# 1         745        Discovery Communications Inc.
# 2        2545        Twenty-First Century Fox Inc.
# 3        1098                          Google Inc.
# 4        1490                   Liberty Global plc
# ..        ...                                  ...
# 95       2445       Texas Instruments Incorporated
# 96        462                Catamaran Corporation
# 97       1794              NXP Semiconductors N.V.
# 98       2661  Vertex Pharmaceuticals Incorporated
# 99       2051                QUALCOMM Incorporated
#
#                             companyname  count
# 0                   Comcast Corporation    188
# 1         Discovery Communications Inc.    182
# 2         Twenty-First Century Fox Inc.    155
# 3                           Google Inc.    155
# 4                    Liberty Global plc    141
# ..                                  ...    ...
# ...

# %% [markdown]
# Column details for clients ( a proposed structure for the cleansed client table, renaming columns to meaningful name, and changing the datatypes as appropriate)
# - ClientID int
# - Name nvarchar
# - Symbol nvarchar
# - LastSale decimal
# - MarketCapLabel nvarchar
# - MarketCapAmount float
# - IPOyear int
# - Sector nvarchar
# - industry nvarchar
# - SummaryQuote nvarchar

# %% [markdown]
# Creation of Cleansed Clients and Sales with:
# 1. Appropriate Data Types (see #3 above)
# 2. Not Null OrderId in Cleansed Sales Table (Nulls Deleted)
# 3. Not Null OrderDate in Cleansed Sales Table ( Nulls Replaced with 9999-12-31
# 4. Null Product Keys Replaced with #Unknown
# 5. Cleansed  Sales Table has the Clientid from Clients
